# %%
from sagemaker.estimator import Estimator

estimator = Estimator(train_instance_count=1,
                      image_name='397262719838.dkr.ecr.us-east-1.amazonaws.com/haibin-test',
                      role='arn:aws:sagemaker:us-east-1:397262719838:notebook-instance/haibin-docker',
                      train_instance_type='local')
estimator.fit()
# Out:
# Creating tmpgy8dk09o_algo-1-8wv1x_1 ...
# Attaching to tmpgy8dk09o_algo-1-8wv1x_12mdone
# algo-1-8wv1x_1  | Vocab file is not found. Downloading.
# algo-1-8wv1x_1  | Downloading /root/.mxnet/models/1569824784.5916433book_corpus_wiki_en_uncased-a6607397.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/vocab/book_corpus_wiki_en_uncased-a6607397.zip...
# algo-1-8wv1x_1  | Downloading /root/.mxnet/models/bert_12_768_12_book_corpus_wiki_en_uncased-75cc780f.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/bert_12_768_12_book_corpus_wiki_en_uncased-75cc780f.zip...
# algo-1-8wv1x_1  | BERTModel(
# algo-1-8wv1x_1  |   (pooler): Dense(768 -> 768, Activation(tanh))
# algo-1-8wv1x_1  |   (word_embed): HybridSequential(
# algo-1-8wv1x_1  |     (0): Embedding(30522 -> 768, float32)
# algo-1-8wv1x_1  |     (1): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |   )
# algo-1-8wv1x_1  |   (token_type_embed): HybridSequential(
# algo-1-8wv1x_1  |     (0): Embedding(2 -> 768, float32)
# algo-1-8wv1x_1  |     (1): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |   )
# algo-1-8wv1x_1  |   (encoder): BERTEncoder(
# algo-1-8wv1x_1  |     (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |     (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |     (transformer_cells): HybridSequential(
# algo-1-8wv1x_1  |       (0): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (1): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (2): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (3): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (4): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (5): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (6): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (7): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (8): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (9): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (10): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |       (11): BERTEncoderCell(
# algo-1-8wv1x_1  |         (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |         (attention_cell): MultiHeadAttentionCell(
# algo-1-8wv1x_1  |           (proj_value): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_query): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (proj_key): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |           (_base_cell): DotProductAttentionCell(
# algo-1-8wv1x_1  |             (_dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |           )
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |         (proj): Dense(768 -> 768, linear)
# algo-1-8wv1x_1  |         (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         (ffn): BERTPositionwiseFFN(
# algo-1-8wv1x_1  |           (ffn_2): Dense(3072 -> 768, linear)
# algo-1-8wv1x_1  |           (layer_norm): BERTLayerNorm(eps=1e-12, center=True, scale=True, axis=-1, in_channels=768)
# algo-1-8wv1x_1  |           (activation): GELU()
# algo-1-8wv1x_1  |           (ffn_1): Dense(768 -> 3072, linear)
# algo-1-8wv1x_1  |           (dropout_layer): Dropout(p = 0.1, axes=())
# algo-1-8wv1x_1  |         )
# algo-1-8wv1x_1  |       )
# algo-1-8wv1x_1  |     )
# algo-1-8wv1x_1  |   )
# algo-1-8wv1x_1  | )
# algo-1-8wv1x_1  | Downloading /root/.mxnet/datasets/imdb/train.json from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/imdb/train.json...
# algo-1-8wv1x_1  | Downloading /root/.mxnet/datasets/imdb/test.json from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/imdb/test.json...
# algo-1-8wv1x_1  | Vocab(size=30522, unk="[UNK]", reserved="['[MASK]', '[SEP]', '[CLS]', '[PAD]']")
# algo-1-8wv1x_1  | Index for [CLS] =  2
# algo-1-8wv1x_1  | Index for [SEP] =  3
# algo-1-8wv1x_1  | words =  [    2 22953  2213  4381  2152  2003  1037  9476  4038  1012  2009  2743
# algo-1-8wv1x_1  |   2012  1996  2168  2051  2004  2070  2060  3454  2055  2082  2166  1010
# algo-1-8wv1x_1  |   2107  2004  1000  5089  1000  1012  2026  3486  2086  1999  1996  4252
# algo-1-8wv1x_1  |   9518  2599  2033  2000  2903  2008 22953  2213  4381  2152  1005  1055
# algo-1-8wv1x_1  |  18312  2003  2172  3553  2000  4507  2084  2003  1000  5089  1000  1012
# algo-1-8wv1x_1  |   1996 25740  2000  5788 13732  1010  1996 12369  3993  2493  2040  2064
# algo-1-8wv1x_1  |   2156  2157  2083  2037 17203  5089  1005 13433  8737  1010  1996  9004
# algo-1-8wv1x_1  |  10196  4757  1997  1996  2878  3663  1010  2035 10825  2033  1997  1996
# algo-1-8wv1x_1  |   2816  1045  2354  1998  2037  2493  1012  2043  1045  2387  1996  2792
# algo-1-8wv1x_1  |   1999  2029  1037  3076  8385  2699  2000  6402  2091  1996  2082  1010
# algo-1-8wv1x_1  |   1045  3202  7383  1012  1012  1012  1012     3]
# algo-1-8wv1x_1  | Batch 0 Acc 0.34375 Train Loss 1.4141626358032227
# algo-1-8wv1x_1  | Batch 25 Acc 0.5949519230769231 Train Loss 0.6885208934545517
