# %%
from sagemaker.estimator import Estimator

estimator = Estimator(train_instance_count=1,
                      image_name='397262719838.dkr.ecr.us-east-1.amazonaws.com/haibin-test',
                      role='arn:aws:sagemaker:us-east-1:397262719838:notebook-instance/haibin-docker',
                      train_instance_type='local')
estimator.fit()
# Out:
# Creating tmpb6pokrgi_algo-1-cjyu7_1 ...
# Attaching to tmpb6pokrgi_algo-1-cjyu7_12mdone
# algo-1-cjyu7_1  | Vocab file is not found. Downloading.
# algo-1-cjyu7_1  | Downloading /root/.mxnet/models/1569827447.8585835book_corpus_wiki_en_uncased-a6607397.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/vocab/book_corpus_wiki_en_uncased-a6607397.zip...
# algo-1-cjyu7_1  | Downloading /root/.mxnet/models/bert_12_768_12_book_corpus_wiki_en_uncased-75cc780f.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/bert_12_768_12_book_corpus_wiki_en_uncased-75cc780f.zip...
# algo-1-cjyu7_1  | BERTModel(
# algo-1-cjyu7_1  |   (encoder): BERTEncoder(
# algo-1-cjyu7_1  |     (layer_norm): BERTLayerNorm(scale=True, axis=-1, center=True, eps=1e-12, in_channels=768)
# algo-1-cjyu7_1  |     (transformer_cells): HybridSequential(
# algo-1-cjyu7_1  |       (0): BERTEncoderCell(
# algo-1-cjyu7_1  |         (ffn): BERTPositionwiseFFN(
# ...
